# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load a pretrained YOLOv8n model
model = YOLO("yolov8n.pt")

# Run inference on 'bus.jpg' with arguments, saving the output
results = model.predict("bus.jpg", save=True, imgsz=320, conf=0.5)

# Get the path to the saved image (this is auto-generated by YOLO)
output_image_path = results[0].path

# Load the image using OpenCV
image = cv2.imread(output_image_path)

# Convert BGR to RGB for displaying with Matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image using Matplotlib
plt.imshow(image_rgb)
plt.axis('off')  # Hide the axes
plt.show()
# Out:
# image 1/1 c:\Users\Apil Thapa\Desktop\flask\bus.jpg: 192x320 2 persons, 24 bicycles, 6 cars, 4 motorcycles, 1 airplane, 11 buss, 9 trains, 4 boats, 2 traffic lights, 3 fire hydrants, 6 stop signs, 4 parking meters, 15 benchs, 1 bird, 18 cats, 21 dogs, 5 horses, 37 bears, 17 backpacks, 29 umbrellas, 16 handbags, 2 ties, 2 suitcases, 6 frisbees, 1 snowboard, 5 baseball bats, 1 baseball glove, 1 skateboard, 8 tennis rackets, 6 knifes, 7 spoons, 1 chair, 1 couch, 1 bed, 12 dining tables, 1 tv, 1 mouse, 2 remotes, 2 keyboards, 178.1ms
# Speed: 0.0ms preprocess, 178.1ms inference, 0.5ms postprocess per image at shape (1, 3, 192, 320)
# Results saved to runs\detect\predict4

# %%
from ultralytics import YOLO
import cv2

# Load a pretrained YOLOv8n model
model = YOLO("yolov8n.pt")

# Initialize video capture (0 for default webcam)
cap = cv2.VideoCapture(0)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open video capture.")
    exit()

while True:
    # Capture frame-by-frame from webcam
    ret, frame = cap.read()

    if not ret:
        print("Failed to grab frame")
        break

    # Run YOLO inference on the frame
    results = model.predict(frame, imgsz=320, conf=0.5, save=False)  # save=False to avoid saving frames

    # Draw bounding boxes on the frame
    annotated_frame = results[0].plot()

    # Display the resulting frame
    cv2.imshow("YOLOv8 Live Inference", annotated_frame)

    # Press 'q' to quit the video stream
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object and close OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 256x320 13 persons, 2 cars, 11 buss, 2 trains, 2 boats, 5 traffic lights, 1 fire hydrant, 13 stop signs, 2 parking meters, 1 umbrella, 6 handbags, 5 ties, 27 frisbees, 1 baseball bat, 2 baseball gloves, 2 tennis rackets, 16 bottles, 2 oranges, 20 carrots, 6 hot dogs, 4 pizzas, 5 donuts, 1 cake, 1 chair, 2 couchs, 2 beds, 8 dining tables, 1 cell phone, 441.2ms
# Speed: 42.1ms preprocess, 441.2ms inference, 16.4ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 motorcycle, 3 giraffes, 419.9ms
# Speed: 8.7ms preprocess, 419.9ms inference, 2.4ms postprocess per image at shape (1, 3, 256, 320)
#
# ...
